# %% [markdown]
# # Homework02
#
# Some exercises to get started with Python, lists, objects, dicts and datasets.
#
# ## Goals
#
# - Gain experience with a popular scripting language used for ML/AI projects and research
# - Get familiar with Python's notation for lists and objects
# - Experiment with Python's unique functionalities for processing lists and objects
# - Learn to load and process datasets using Python

# %% [markdown]
# ### Setup
#
# Run the following 2 cells to import all necessary libraries and helpers for Homework 02

# %%
# !wget -q https://github.com/PSAM-5020-2026S-A/5020-utils/raw/main/src/data_utils.py

# %%
import matplotlib.pyplot as plt

from Homework02_utils import Tests
from data_utils import object_from_json_url

# %% [markdown]
# ### Exercise 01:
#
# Finding the sum of integer sequences.
#
# Create a function ```sum_of_ints(i0, i1)``` that returns the sum of all integers between two integers.
#
# For example, ```sum_of_ints(4, 32)``` should return $522$.

# %%
## Work on exercise 01 here

def sum_of_ints(i0, i1):
  # TODO: 
  total = i0
  for x in range(i0+1, i1 + 1):
     total += x
  return total 

sum_of_ints(4,32)
# Out:
# 522

# %% [markdown]
# ### Exercise 01 testing:
#
# Running the following cell will test the ```sum_of_ints()``` function on a small set of input pairs and report any combination that isn't computing correctly, if any.

# %%
# Test 01
Tests.test("01", sum_of_ints)
# Out:
# ERROR Check sum of sum_of_ints(-59, -61) should be -180 not -59
# ERROR Check sum of sum_of_ints(-45, -49) should be -235 not -45
# ERROR Check sum of sum_of_ints(93, 77) should be 1445 not 93

# %% [markdown]
# ### Exercise 02:
#
# Working with lists and dictionaries/objects.
#
# Write a function `sum_objects(in_list)` that accept a list of objects and returns a sum according to the following specifications:
#
# Each object in the list has 2 fields, `type` and `amount`, and so will look something like this:
#
# ```python
# test_list = [
#   { "type": "cost", "amount": 10.00 },
#   { "type": "cost", "amount": 15.99 },
#   { "type": "income", "amount": 150.25 },
#   { "type": "income", "amount": 243.52 },
# ]
# ```
#
# The `sum_objects(in_list)` function should iterate through all of the items in `in_list` and sum their `amount`s using positive values when `type` is `"income"`, and negative values when `type` is `"cost"`.
#
# For example, passing the above list to the function should return $367.78$.

# %%
# Implement 02 here

def sum_objects(in_list):
  # TODO: 
  total = 0
  for item in in_list:
    if item["type"] =="income":
      total += item["amount"]
    elif item["type"] == "cost":
      total -= item["amount"]
  
  return total

# %%
# Run this cell to test if function returns 367.78

test_list = [
  { "type": "cost", "amount": 10.00 },
  { "type": "cost", "amount": 15.99 },
  { "type": "income", "amount": 150.25 },
  { "type": "income", "amount": 243.52 },
]

sum_objects(test_list)
# Out:
# 367.78

# %% [markdown]
# #### Exercise 02 test:
#
# Run the following cell to test the `sum_objects()` function.

# %%
# Test 02
Tests.test("02", sum_objects)
# Out:
# 02: All tests passed 🎉🎉🎉

# %% [markdown]
# ### Exercise 03:
#
# Working with data files.
#
# Find the name and population of the 3 cities that are geographically closest to the world's most populous city.
#
# # 🤔😱

# %% [markdown]
# #### Load Data:
#
# Let's break this down into a few sub-problems.
#
# First, let's load a JSON file that has information about large cities in the world.
#
# The file at this [URL](https://raw.githubusercontent.com/PSAM-5020-2025S-A/5020-utils/main/datasets/json/cities50k.json) has a list of cities formatted like this:
#
# ```py
# {
#   "name": "Pittsburgh",
#   "country": "US",
#   "admin1": "Pennsylvania",
#   "lat": 40.4406200,
#   "lon": -79.9958900,
#   "pop": 304391
# }
# ```
#
# This is just like how we loaded ANSUR data files in class:

# %%
# Define the location of the json file here
CITIES_FILE = "https://raw.githubusercontent.com/PSAM-5020-2026S-A/5020-utils/main/datasets/json/cities50k.json"

# Use the object_from_json_url() function to load contents from 
# the json file into a Python object called "info_cities"

info_cities = object_from_json_url(CITIES_FILE)

# %% [markdown]
# #### Exercise 03A:
#
# Ok. We should now have a list of objects with information about cities.
#
# Explore the data and answer the following questions:
# - How many cities are in this list?
# - What's the name of the first city on the list?
# - What are the latitude and longitude of the last city on the list?
# - What are the populations for the largest and smallest cities?
# - What's the name of the city with the largest population?

# %%
# Work on 03A here

# How many cities are in the list?

num_cities = len(info_cities)
print(num_cities)

# What's the name of the first city on the list?
first_city = info_cities[0]["name"]
print(first_city)


# What are the latitude and longitude of the last city on the list?

last_latitude = info_cities[-1]["lat"]
last_longitude = info_cities[-1]["lon"]
print(last_latitude)
print(last_longitude)

# What are the populations for the largest and smallest cities?

largest_population = max(city["pop"] for city in info_cities)
smallest_population = min(city["pop"] for city in info_cities)
print(largest_population)
print(smallest_population)

# What's the name of the city with the largest population?
largest_city_name = None
for city in info_cities:
  if city["pop"] == largest_population:
    largest_city_name = city["name"]
    break

# largest_city_name = max(info_cities, key=lambda c: c["pop"])["name"]

print(largest_city_name)
# Out:
# 8670
# Abu Dhabi
# -17.88333
# 30.7
# 22315474
# 50011
# Shanghai

# %% [markdown]
# #### Test 03A

# %%
# Test 03A
answers = [num_cities, first_city, last_latitude, last_longitude, largest_population, smallest_population, largest_city_name]

Tests.test("03A", answers)
# Out:
# 03A: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03B:
#
# We have the largest city's name and population, but we need its position.
#
# We can recycle some of the logic from above to get the whole object that contains information for the largest city.

# %%
# Work on 03B here
largest_city ={}
for city in info_cities:
  if city["pop"] == largest_population:
    largest_city = city
    break

# %%
# Test 03B
Tests.test("03B", largest_city)
# Out:
# 03B: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03C:
#
# We should have all info about the largest city here.
#
# Now, we'll iterate through the list and use each city's latitude and longitude to calculate its distance from the largest city.
#
# Althought not $100\%$ correct, it's ok to use the [2D Euclidean distances](https://en.wikipedia.org/wiki/Euclidean_distance#Two_dimensions) for this.
#
# Could be useful to define a function `distance(cityA, cityB)` that returns the distance between two cities.

# %%
# Work on 03C here

# Implement the helper function for calculating distances between 2 cities

def distance(cityA, cityB):
  a = cityA["lat"]
  b = cityA["lon"]
  c = cityB["lat"]
  d = cityB["lon"]
  return ((a-c)**2 + (b-d)**2)**0.5

# %%
# Test 03C
Tests.test("03C", distance)
# Out:
# 03C: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03D:
#
# Ok. We implemented a function to calculate the distance between 2 cities, let's use it now.
#
# Iterate through the list of cities again, calculate the distance from each city to the largest city, and add that as a new feature/key to each city's entry:
#
# ```py
# {
#   "name": "Pittsburgh",
#   "country": "US",
#   "admin1": "Pennsylvania",
#   "lat": 40.4406200,
#   "lon": -79.9958900,
#   "pop": 304391,
#   "distance": 1222.32
# }
# ```
#
# Just make sure the key that holds the distance value is called `distance`.

# %%
# Work on 03D here

# Now calculate every city's distance from the largest city and
# add that info to each city's entry

for city in info_cities:
  city["distance"] =distance(city, largest_city)
  print("distance from " + largest_city_name + " to " +city["name"] +  " is "+  str(city["distance"]))
# Out:
# distance from Shanghai to Abu Dhabi is 67.40206314269321
# distance from Shanghai to Ajman City is 66.235511831048
# distance from Shanghai to Al Ain City is 66.0726126284749
# distance from Shanghai to Al Fujairah City is 65.40228606844411
# distance from Shanghai to Al Shamkhah City is 67.09874187855165
# distance from Shanghai to Bani Yas City is 67.18516412019845
# distance from Shanghai to Dubai is 66.43359899000656
# distance from Shanghai to Khalifah A City is 67.19763291038755
# distance from Shanghai to Musaffah is 67.32612877090291
# distance from Shanghai to Ras Al Khaimah City is 65.73972164114859
# distance from Shanghai to Reef Al Fujairah City is 65.49300750447561
# distance from Shanghai to Sharjah is 66.30765849826474
# distance from Shanghai to Umm Al Quwain City is 66.14528028100118
# distance from Shanghai to Zayed City is 68.17420964139738
# distance from Shanghai to Baghlān is 52.97764825494333
# distance from Shanghai to Balkh is 54.840806328832365
# distance from Shanghai to Bāmyān is 53.751366272439995
# distance from Shanghai to Bāzārak is 52.10370015965181
# distance from Shanghai to Charikar is 52.423949658729455
# distance from Shanghai to Gardez is 52.28611784238719
# distance from Shanghai to Ghazni is 53.08832974078296
# distance from Shanghai to Herāt is 59.340781498010294
# distance from Shanghai to Jalālābād is 51.10707701193055
# distance from Shanghai to Kabul is 52.39013840944686
# distance from Shanghai to Kandahār is 55.749301865538186
# distance from Shanghai to Khanabad is 52.626532889108326
# distance from Shanghai to Khōst is 51.58112333467157
# distance from Shanghai to Khulm is 54.03788720943483
# distance from Shanghai to Kunduz is 52.888520384072955
# distance from Shanghai to Maymana is 56.86893248067349
# distance from Shanghai to Mazār-e Sharīf is 54.62345883051072
# distance from Shanghai to Pul-e Khumrī is 52.9539271802687
# distance from Shanghai to Sar-e Pul is 55.749629324268156
# distance from Shanghai to Shibirghān is 55.97067703046034
# distance from Shanghai to Taloqan is 52.215489712071076
# distance from Shanghai to Durrës is 102.50231392083694
# distance from Shanghai to Elbasan is 101.85714787968492
# distance from Shanghai to Fier is 102.34397464722288
# distance from Shanghai to Korçë is 101.11477036271704
# distance from Shanghai to Patos is 102.27715837828357
# distance from Shanghai to Pogradec is 101.26928827533054
# distance from Shanghai to Shkodër is 102.52081695906448
# distance from Shanghai to Tirana is 102.14028373843153
# distance from Shanghai to Vlorë is 102.3932209382965
# distance from Shanghai to Gyumri is 78.20080831071249
# distance from Shanghai to Vanadzor is 77.55838551943434
# distance from Shanghai to Yerevan is 77.46425043744115
# distance from Shanghai to Benguela is 116.59189103886472
# distance from Shanghai to Cabinda is 115.280179730481
# distance from Shanghai to Cuito is 113.25574233731109
# distance from Shanghai to Huambo is 114.50911206371744
# distance from Shanghai to Lobito is 116.3914185806965
# distance from Shanghai to Luanda is 115.39975990143654
# distance from Shanghai to Lubango is 117.41126630645672
# distance from Shanghai to Malanje is 112.74384914675791
# distance from Shanghai to N’dalatando is 113.99130457309101
# distance from Shanghai to Namibe is 118.75364423079613
# distance from Shanghai to Soio is 115.30824132328443
# distance from Shanghai to San Luis is 198.56722531850266
# distance from Shanghai to San Martín is 200.51650656991436
# distance from Shanghai to San Miguel is 191.79798022019784
# distance from Shanghai to San Miguel de Tucumán is 195.49692766712522
# distance from Shanghai to San Nicolás de los Arroyos is 192.79811335321853
# distance from Shanghai to San Pedro de Jujuy is 194.4011241192296
# distance from Shanghai to San Rafael is 200.88412577428937
# distance from Shanghai to San Ramón de la Nueva Orán is 193.57169384885617
# distance from Shanghai to San Salvador de Jujuy is 194.80379326577935
# distance from Shanghai to Santa Fe is 192.71089116987784
# distance from Shanghai to Santa Rosa is 197.74220327376807
# distance from Shanghai to Santiago del Estero is 194.87123054091745
# distance from Shanghai to Santo Tomé is 192.7689578845391
# distance from Shanghai to Tandil is 193.16172912205073
# distance from Shanghai to Tartagal is 192.8960088441049
# distance from Shanghai to Trelew is 201.0632100063087
# distance from Shanghai to Ushuaia is 208.3646973518415
# distance from Shanghai to Venado Tuerto is 194.59250692222582
# distance from Shanghai to Villa Carlos Paz is 196.2247202860924
# distance from Shanghai to Villa María is 195.35141415162906
# distance from Shanghai to Villa Mercedes is 197.86179836637743
# distance from Shanghai to Yerba Buena is 195.58454059307707
# distance from Shanghai to Zárate is 191.94315994329986
# distance from Shanghai to Graz is 107.18561181784662
# distance from Shanghai to Innsbruck is 111.22622959618833
# distance from Shanghai to Klagenfurt am Wörthersee is 108.25412356108382
# distance from Shanghai to Linz is 108.5250926347976
# distance from Shanghai to Salzburg is 109.67412549120691
# distance from Shanghai to Vienna is 106.44997210461496
# distance from Shanghai to Villach is 108.69697461997966
# distance from Shanghai to Adelaide is 68.33548174044945
# distance from Shanghai to Adelaide Hills is 68.3459283625016
# distance from Shanghai to Ballarat is 72.34106162971139
# distance from Shanghai to Bendigo is 71.70904185744222
# distance from Shanghai to Brisbane is 66.64234145816381
# distance from Shanghai to Bunbury is 64.81087783701899
# distance from Shanghai to Bundaberg is 64.03197791018563
# distance from Shanghai to Cairns is 53.934293618247196
# distance from Shanghai to Canberra is 72.03217979252398
# distance from Shanghai to Darwin is 44.67986774808762
# distance from Shanghai to Geelong is 73.05227173446283
# distance from Shanghai to Gold Coast is 67.30205724532127
# distance from Shanghai to Hervey Bay is 64.60464011598238
# distance from Shanghai to Hobart is 78.48803035698437
# distance from Shanghai to Launceston is 77.06429987778063
# distance from Shanghai to Logan City is 66.83167728432753
# distance from Shanghai to Mackay is 59.25297676825443
# distance from Shanghai to Maitland is 70.68416135546633
# distance from Shanghai to Mandurah is 64.00668814134973
# distance from Shanghai to Melbourne is 72.92802561125593
# distance from Shanghai to Newcastle is 70.9568399650386
# distance from Shanghai to Perth is 63.421881077804684
# distance from Shanghai to Rockhampton is 61.848341027902286
# distance from Shanghai to Rockingham is 63.7568919622028
# distance from Shanghai to Sydney is 71.56630270701778
# distance from Shanghai to Toowoomba is 66.22242099295676
# distance from Shanghai to Townsville is 56.4942659599096
# distance from Shanghai to Wollongong is 71.94350828768708
# distance from Shanghai to Bakıxanov is 72.08024228202413
# distance from Shanghai to Baku is 72.1493019876492
# distance from Shanghai to Ganja is 75.69106091054346
# distance from Shanghai to Lankaran is 72.99707029187678
# distance from Shanghai to Mingelchaur is 75.00790543371944
# distance from Shanghai to Nakhchivan is 76.4640875116842
# distance from Shanghai to Qaraçuxur is 72.07077857637589
# distance from Shanghai to Saatlı is 73.60628432644864
# distance from Shanghai to Sheki is 74.95350540920951
# distance from Shanghai to Şirvan is 73.0508420936898
# distance from Shanghai to Sumqayıt is 72.39803303648864
# distance from Shanghai to Xankandi is 75.19812596134295
# distance from Shanghai to Yevlakh is 74.89962396391853
# distance from Shanghai to Banja Luka is 105.14178027825095
# distance from Shanghai to Bihać is 106.45881621994161
# distance from Shanghai to Mostar is 104.35633094178858
# distance from Shanghai to Sarajevo is 103.87189479662341
# distance from Shanghai to Tuzla is 103.64991411468175
# distance from Shanghai to Zenica is 104.36434351448295
# distance from Shanghai to Bridgetown is 181.9821130446696
# distance from Shanghai to Azimpur is 31.96320629930608
# distance from Shanghai to Bagerhat is 32.804854551901315
# distance from Shanghai to Barisāl is 32.23356851556154
# distance from Shanghai to Bhairab Bāzār is 31.313542041551294
# distance from Shanghai to Bhola is 31.974120067295054
# distance from Shanghai to Bibir Hat is 30.87182568480361
# distance from Shanghai to Bogra is 32.71340680299134
# distance from Shanghai to Chittagong is 30.929672641280895
# distance from Shanghai to Comilla is 31.251872467269866
# distance from Shanghai to Cox’s Bāzār is 31.030820998165677
# distance from Shanghai to Dhaka is 31.946336912027967
# distance from Shanghai to Dinājpur is 33.293716737934204
# distance from Shanghai to Farīdpur is 32.52178080404578
# distance from Shanghai to Feni is 31.161830602260835
# distance from Shanghai to Habiganj is 30.8142204975771
# distance from Shanghai to Ishurdi is 33.15995734735647
# distance from Shanghai to Jamālpur is 32.134073931085986
# distance from Shanghai to Jessore is 33.234635912291864
# distance from Shanghai to Joypur Hāt is 33.00326014624768
# distance from Shanghai to Khagrachhari is 30.584051892491285
# distance from Shanghai to Khulna is 32.984468535566855
# distance from Shanghai to Kishorganj is 31.416093519896776
# distance from Shanghai to Kushtia is 33.15661169982995
# distance from Shanghai to Lākshām is 31.36915813850445
# distance from Shanghai to Lakshmīpur is 31.72694369280628
# distance from Shanghai to Lalmonirhat is 32.44870613680922
# distance from Shanghai to Mādārīpur is 32.269250118752375
# distance from Shanghai to Maulavi Bāzār is 30.4413245866815
# distance from Shanghai to Mymensingh is 31.717648211990756
# distance from Shanghai to Nāgarpur is 32.38355078248987
# distance from Shanghai to Narail is 32.96522716598508
# distance from Shanghai to Nārāyanganj is 31.876469275884375
# distance from Shanghai to Narsingdi is 31.595092453132654
# distance from Shanghai to Natore is 33.177979974358
# distance from Shanghai to Nawābganj is 33.83985316731295
# distance from Shanghai to Netrakona is 31.37603345447604
# distance from Shanghai to Pābna is 33.018953650108294
# distance from Shanghai to Pālang is 32.120520063199486
# distance from Shanghai to Paltan is 31.93363845979503
# distance from Shanghai to Pār Naogaon is 33.136784305627785
# distance from Shanghai to Patiya is 30.80101553825296
# distance from Shanghai to Pirojpur is 32.6475705118681
# distance from Shanghai to Puthia is 33.33654835139655
# distance from Shanghai to Rāipur is 31.762215371960444
# distance from Shanghai to Rājshāhi is 33.563005065917444
# distance from Shanghai to Rāmganj is 31.667345676158273
# distance from Shanghai to Rangpur is 32.66855027846201
# distance from Shanghai to Saidpur is 33.01834886692247
# distance from Shanghai to Sandwīp is 31.241327404887908
# distance from Shanghai to Sarishābāri is 32.28200229450615
# distance from Shanghai to Sātkania is 30.7978354240846
# distance from Shanghai to Sātkhira is 33.48664876583801
# distance from Shanghai to Shāhzādpur is 32.628965726331266
# distance from Shanghai to Sherpur is 32.04669218391502
# distance from Shanghai to Shibganj is 32.73196890102397
# distance from Shanghai to Sirajganj is 32.462649853973716
# distance from Shanghai to Sonārgaon is 31.75735903472611
# distance from Shanghai to Sylhet is 30.25423499410951
# distance from Shanghai to Tāngāil is 32.30295552955643
# distance from Shanghai to Thākurgaon is 33.39413775666921
# distance from Shanghai to Tungi is 31.90921271686282
# distance from Shanghai to Tungipāra is 32.63384099906261
# distance from Shanghai to Aalst is 119.06591576074995
# distance from Shanghai to Antwerpen is 118.75052078449552
# distance from Shanghai to Brugge is 119.91123537301415
# distance from Shanghai to Brussels is 118.74279293940876
# distance from Shanghai to Charleroi is 118.57656175803041
# distance from Shanghai to Deurne is 118.6891680105076
# distance from Shanghai to Genk is 117.62592771385907
# distance from Shanghai to Gent is 119.39922855220004
# distance from Shanghai to Hasselt is 117.78094427456463
# distance from Shanghai to Kortrijk is 119.80825492482644
# distance from Shanghai to La Louvière is 118.84198472916296
# distance from Shanghai to Leuven is 118.40033615304392
# distance from Shanghai to Liège is 117.50502514958669
# distance from Shanghai to Mechelen is 118.64485975795158
# distance from Shanghai to Mons is 119.06919142053918
# distance from Shanghai to Mouscron is 119.85238931849211
# distance from Shanghai to Namur is 118.1682094163333
# distance from Shanghai to Ostend is 120.20542346228683
# distance from Shanghai to Roeselare is 119.9679465441207
# distance from Shanghai to Seraing is 117.56219114455166
# distance from Shanghai to Sint-Niklaas is 118.9973828537691
# distance from Shanghai to Tournai is 119.64950010882829
# distance from Shanghai to Verviers is 117.2067795728771
# distance from Shanghai to Banfora is 127.89286475407846
# distance from Shanghai to Bobo-Dioulasso is 127.34349730876131
# distance from Shanghai to Koudougou is 125.2654417809497
# distance from Shanghai to Ouagadougou is 124.42904468007941
# distance from Shanghai to Ouahigouya is 125.12919343639678
# distance from Shanghai to Asenovgrad is 97.19267859738511
# distance from Shanghai to Blagoevgrad is 98.94861352119139
# distance from Shanghai to Burgas is 94.66515800550962
# distance from Shanghai to Dobrich is 94.43503329472279
# distance from Shanghai to Gabrovo is 96.82759412988686
# distance from Shanghai to Haskovo is 96.49887580964351
# distance from Shanghai to Kardzhali is 96.65554214767253
# distance from Shanghai to Kazanlak is 96.73150666544021
# distance from Shanghai to Pazardzhik is 97.74315746537606
# distance from Shanghai to Pernik is 99.08017638913094
# distance from Shanghai to Pleven is 97.60614441690954
# distance from Shanghai to Plovdiv is 97.32350818117892
# distance from Shanghai to Ruse is 96.33570773065199
# distance from Shanghai to Shumen is 95.29988700694456
# distance from Shanghai to Sliven is 95.81711781756013
# distance from Shanghai to Kitwe is 103.11531471780224
# distance from Shanghai to Livingstone is 107.45873758341712
# distance from Shanghai to Luanshya is 103.07483951059346
# distance from Shanghai to Lusaka is 104.1877029445078
# distance from Shanghai to Mazabuka is 104.87104025962792
# distance from Shanghai to Mongu is 108.75858865187338
# distance from Shanghai to Mufulira is 102.98284239029384
# distance from Shanghai to Ndola is 102.7996903407447
# distance from Shanghai to Bulawayo is 106.13585850362402
# distance from Shanghai to Chinhoyi is 103.38720301079674
# distance from Shanghai to Chitungwiza is 102.92268651809327
# distance from Shanghai to Gweru is 104.71780288403926
# distance from Shanghai to Harare is 102.85380201042497
# distance from Shanghai to Kadoma is 104.09523123202331
# distance from Shanghai to Kwekwe is 104.46784050288443
# distance from Shanghai to Marondera is 102.58758345763391
# distance from Shanghai to Masvingo is 104.13509529242532
# distance from Shanghai to Mutare is 101.99262768438905
# distance from Shanghai to Norton is 103.19099038077937

# %%
# Test 03D
Tests.test("03D", info_cities)
# Out:
# 03D: All tests passed 🎉🎉🎉

# %% [markdown]
# #### Exercise 03E:
#
# Now, sort the array from the previous step by distance and get the name and population of the $3$ cities closest to the largest city, but not including the largest city. In other words, if you sort the list from the exercise above by ascending `distance`, the $3$ cities closest to the largest city will be in the slice `[1:4]`. The city at index $0$ is the city with the largest population, and should have a distance of $0$ from itself.
#
# The answer should be an object where its keys are city names and values are populations.
#
# Something like:
#
# ```python
# closest_3 = {
#   "pittsburgh": 23412,
#   "liverpool": 172821,
#   "oakland": 182726
# }
# ```
#
# We saw how to sort lists of objects in lecture.

# %%
# Work on 03E here

# Sort the array and get the name and population of the 3 cities closest to the largest city

def get_distance(city):
  return city["distance"]

cities_by_distance = []
cities_by_distance = sorted(info_cities, key=get_distance)

closest_3 = {}
for city in cities_by_distance [1:4]:
  closest_3[city["name"]]= city["pop"]
print(closest_3)
# Out:
# {'Songjiang': 130218, 'Zhujiajiao': 60000, 'Kunshan': 1600000}

# %%
# Test 03E
Tests.test("03E", closest_3)
# Out:
# 03E: All tests passed 🎉🎉🎉

# %% [markdown]
# ### Exercise 04:
#
# Visualizing data files.

# %% [markdown]
# #### Loading The Data:
#
# Let's load a JSON file that has information about houses in the Los Angeles metropolitan region of California.
#
# The file at this [url](https://raw.githubusercontent.com/PSAM-5020-2025S-A/5020-utils/main/datasets/json/LA_housing.json) has a list of objects formatted like this:
#
# ```python
# {
#   "longitude": -114.310,
#   "latitude": 34.190,
#   "age": 15,
#   "rooms": 12.234,
#   "bedrooms": 3.514,
#   "value": 669000
# }
# ```
#
# The number of rooms and bedrooms are not integers because some addresses have multiple units/apartments with different floorplans that get averaged.

# %%
# Define the location of the json file
HOUSES_FILE = "https://raw.githubusercontent.com/PSAM-5020-2026S-A/5020-utils/main/datasets/json/LA_housing.json"

# Use the object_from_json_url() function to load
# the json file into a Python object called "info_houses"

info_houses = object_from_json_url(HOUSES_FILE)

# %% [markdown]
# #### Exercise 04A:
#
# Explore the data and answer the following questions:
# - How many instances are there in our dataset?
# - What's the value of the most expensive house?
# - What's the max number of bedrooms in a house?
# - What's the number of bedrooms in the house with the most rooms?
# - What's the number of rooms in the house with the most bedrooms?

# %%
# Work on 04A here

# How many instances are there in our dataset?
# This is the same as asking "how many rows" or, in this case, "how many houses"

num_houses = 0


# What's the value of the most expensive house?

max_value = 0


# What's the number of bedrooms in the house with the most bedrooms?

most_bedrooms = 0


# What's the number of bedrooms in the house with the most rooms?

bedrooms_in_most_rooms = 0


# What's the number of rooms in the house with the most bedrooms?

rooms_in_most_bedrooms = 0

# %%
# Test 04A
answers = [num_houses, max_value, most_bedrooms, bedrooms_in_most_rooms, rooms_in_most_bedrooms]

Tests.test("04A", answers)

# %% [markdown]
# #### Exercise 04B:
#
# Which of the features (`longitude`, `latitude`, `age`, `rooms` or `bedrooms`) is a better indicator for value of a house?
#
# We're going to use XY scatter plots to visualize house value as a function of each of these features, and see if any of them show strong correlation.
#
# Documentation for the plotting library is here:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
#
# One thing to note is that the functions for plotting like to get lists of values and not lists of objects.
#
# Before we plot anything, let's define a function `list_from_key(objs, key)` that returns a list with all values of feature `key` for all of the objects in `objs`.

# %%
# Work on 04B here

# helper function to get lists of values from specific key
def list_from_key(objs, key):
  # TODO: implement the list_from_key functionality
  return []

# %%
# Test 04B
Tests.test("04B", list_from_key)

# %% [markdown]
# #### Exercise 04C:
#
# Now we can actually plot some values and start looking for correlations.
#
# Pick a feature and make a graph that shows house prices as a function of that feature.
#
# You can also write a for loop to plot graphs for all features.

# %%
# Work on 04C here

# TODO: get a list with all of the price values
prices = []

# TODO: get a list with all of the house ages (for example)
house_ages = []


# this is the command to plot a XY scatter plot from 2 lists
# see documentation: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

plt.scatter(house_ages, prices)
plt.xlabel("age")
plt.ylabel("value")
plt.show()

# %% [markdown]
# #### What are some features that correlate with price ?

# %% [markdown]
# ### <span style="color:hotpink">Interpretation</span>
#
# <span style="color:hotpink">Answer 04C here. Double-click to edit Markdown.</span>

# %% [markdown]
# #### Foreshadowing:
#
# What if we use two features at a time?
#
# Is there a pair of features (`longitude`, `latitude`, `age`, `rooms` or `bedrooms`) that correlates to house value?
#
# We could look at the relationship between `price`, `age` and `rooms`:

# %%
# get a list with all of the price values
prices = list_from_key(info_houses, "value")

# get a list with all of the values of one feature
feature_0_values = list_from_key(info_houses, "age")

# get a list with all of the values of another feature
feature_1_values = list_from_key(info_houses, "rooms")

# this is how we plot an XY scatter plot using 3 lists
# see documentation: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

plt.scatter(feature_0_values, feature_1_values, c=prices, alpha=0.3)
plt.xlabel("age")
plt.ylabel("rooms")
plt.show()

# %% [markdown]
# Or, we could write a little for loop to plot all possible pairs of features:

# %%
# to plot all feature pairs
# get list of all features
features = info_houses[0].keys()
prices = list_from_key(info_houses, "value")

# get all pairs of features
for idx_0, feature_0 in enumerate(features):
  x = list_from_key(info_houses, feature_0)
  for idx_1, feature_1 in enumerate(features):
    y = list_from_key(info_houses, feature_1)
    # skip repeated features
    if feature_0 != "value" and feature_1 != "value" and idx_1 > idx_0:
      plt.scatter(x, y, c=prices, alpha=0.3)
      plt.xlabel(feature_0)
      plt.ylabel(feature_1)
      plt.show()
